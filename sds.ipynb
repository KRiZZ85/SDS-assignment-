# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\hp\Downloads\smart_city_citizen_activity.csv")
df
# Out:
#      Citizen_ID  Age  Gender Mode_of_Transport  Work_Hours  Shopping_Hours  \
# 0          1001   56  Female           Walking           5               2
# 1          1002   69    Male           Bicycle           0               2
# 2          1003   46    Male              Bike           0               4
# 3          1004   32    Male               Car           7               2
# 4          1005   60    Male           Walking           3               3
# ..          ...  ...     ...               ...         ...             ...
# 995        1996   60    Male               Car           2               2
# 996        1997   64  Female           Walking           9               0
# 997        1998   62  Female                EV           8               3
# 998        1999   35  Female               Car           9               3
# 999        2000   55    Male               Car           4               0
#
# ...

# %%
df.head()
# Out:
#    Citizen_ID  Age  Gender Mode_of_Transport  Work_Hours  Shopping_Hours  \
# 0        1001   56  Female           Walking           5               2
# 1        1002   69    Male           Bicycle           0               2
# 2        1003   46    Male              Bike           0               4
# 3        1004   32    Male               Car           7               2
# 4        1005   60    Male           Walking           3               3
#
#    Entertainment_Hours  Home_Energy_Consumption_kWh  Charging_Station_Usage  \
# 0                    0                         5.32                       0
# 1                    2                         2.19                       0
# 2                    0                         4.68                       0
# 3                    3                         3.42                       0
# 4                    1                         2.79                       0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Citizen_ID                   1000 non-null   int64
#  1   Age                          1000 non-null   int64
#  2   Gender                       1000 non-null   object
#  3   Mode_of_Transport            1000 non-null   object
#  4   Work_Hours                   1000 non-null   int64
#  5   Shopping_Hours               1000 non-null   int64
#  6   Entertainment_Hours          1000 non-null   int64
#  7   Home_Energy_Consumption_kWh  1000 non-null   float64
#  8   Charging_Station_Usage       1000 non-null   int64
#  9   Carbon_Footprint_kgCO2       1000 non-null   float64
#  10  Steps_Walked                 1000 non-null   int64
#  11  Calories_Burned              1000 non-null   int64
#  12  Sleep_Hours                  1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Citizen_ID         Age   Work_Hours  Shopping_Hours  \
# count  1000.000000  1000.00000  1000.000000     1000.000000
# mean   1500.500000    43.81900     4.397000        2.024000
# std     288.819436    14.99103     2.870127        1.421071
# min    1001.000000    18.00000     0.000000        0.000000
# 25%    1250.750000    31.00000     2.000000        1.000000
# 50%    1500.500000    44.00000     4.000000        2.000000
# 75%    1750.250000    56.00000     7.000000        3.000000
# max    2000.000000    69.00000     9.000000        4.000000
#
#        Entertainment_Hours  Home_Energy_Consumption_kWh  \
# count          1000.000000                  1000.000000
# mean              1.532000                     5.996900
# std               1.102811                     2.302009
# min               0.000000                     2.000000
# 25%               1.000000                     4.050000
# 50%               2.000000                     5.870000
# ...

# %%
df.isnull().sum()
# Out:
# Citizen_ID                     0
# Age                            0
# Gender                         0
# Mode_of_Transport              0
# Work_Hours                     0
# Shopping_Hours                 0
# Entertainment_Hours            0
# Home_Energy_Consumption_kWh    0
# Charging_Station_Usage         0
# Carbon_Footprint_kgCO2         0
# Steps_Walked                   0
# Calories_Burned                0
# Sleep_Hours                    0
# Social_Media_Hours             0
# Public_Events_Hours            0
# dtype: int64

# %%
age_mean = df['Age'].mean()
df['Age'] = df['Age'].fillna(age_mean)

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Mode_of_Transport'] = df['Mode_of_Transport'].fillna(df['Mode_of_Transport'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Citizen_ID                     0
# Age                            0
# Gender                         0
# Mode_of_Transport              0
# Work_Hours                     0
# Shopping_Hours                 0
# Entertainment_Hours            0
# Home_Energy_Consumption_kWh    0
# Charging_Station_Usage         0
# Carbon_Footprint_kgCO2         0
# Steps_Walked                   0
# Calories_Burned                0
# Sleep_Hours                    0
# Social_Media_Hours             0
# Public_Events_Hours            0
# dtype: int64

# %%
# Histogram for Age
df['Age'].hist(bins=20, color='skyblue', alpha=0.7)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Histogram for Work Hours
df['Work_Hours'].hist(bins=20, color='orange', alpha=0.7)
plt.title('Distribution of Work Hours')
plt.xlabel('Work Hours')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot for Age
sns.boxplot(y=df['Age'], color='lightblue')
plt.title('Boxplot of Age')
plt.show()

# %%
# Select only numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Calculate the correlation matrix
corr_matrix = df[numerical_cols].corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, square=True)
plt.title('Correlation Matrix for Numerical Features', fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df.to_csv('cleaned_smart_city_citizen.csv', index=False)

# %%
plt.hist(df['Home_Energy_Consumption_kWh'], bins=10, edgecolor='black') 
plt.ylabel('Frequency')
plt.title('Histogram of Home Energy Consumption')
plt.show()

# %%
sns.histplot(df['Work_Hours'])
# Out:
# <Axes: xlabel='Work_Hours', ylabel='Count'>

# %%
sns.countplot(x='Mode_of_Transport', data=df)
# Out:
# <Axes: xlabel='Mode_of_Transport', ylabel='count'>

# %%
gender_counts = df['Gender'].value_counts()
plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
sns.barplot(x='Mode_of_Transport', y='Home_Energy_Consumption_kWh', data=df)
plt.xticks(rotation='vertical')
plt.title('Average Home Energy Consumption by Mode of Transport')
plt.ylabel('Average Home Energy Consumption (kWh)')
plt.xlabel('Mode of Transport')
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
sns.barplot(x='Age', y='Work_Hours', data=df)
plt.xticks(rotation='vertical')
plt.title('Average Work Hours by Age Group')
plt.ylabel('Average Work Hours')
plt.xlabel('Age Group')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Gender', y='Mode_of_Transport', data=df)
plt.xticks(rotation='vertical')
plt.title('Proportion of Mode of Transport by Gender')
plt.xlabel('Gender')
plt.ylabel('Proportion')
plt.show()

# %%
from sklearn import datasets, decomposition 
iris = datasets.load_iris() 
X = iris.data 
y = iris.target 
pca = decomposition.PCA(n_components=2) 
X = pca.fit_transform(X) 
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
# Out:
# <Axes: >
